# %%
print("hello pihu")
# Out:
# hello pihu

# %%
a=10      #int
b=20.54   #float
c=True    #boolean
d=3+4j    #complex

# %%
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
# Out:
# 10 <class 'int'>
# 20.54 <class 'float'>
# True <class 'bool'>
# (3+4j) <class 'complex'>

# %% [markdown]
# # complex no.
# root(-395)
# root(395)Xroot(-1)
#             j

# %%
x=3+4j
y=6+2j
x+y
# Out:
# (9+6j)

# %%
x=2+5j
y=4+6j
x+y
# Out:
# (6+11j)

# %% [markdown]
# # container datatypes
#
# # .list
# # .tuple
# # .set
# # .dictionary

# %%
# list
L=[1,2,34,5,5,34,4,3]
print(L)
# Out:
# [1, 2, 34, 5, 5, 34, 4, 3]

# %%
L1=["hello","this","is",'list',1,3,5,4.64,False,True]
print(L1)
# Out:
# ['hello', 'this', 'is', 'list', 1, 3, 5, 4.64, False, True]

# %%
type(L1)
# Out:
# list

# %%
len(L1)
# Out:
# 10

# %%
len(L)
# Out:
# 8

# %%
#tuple
x=(1,2,3,5,3,5,3)
print(x)
# Out:
# (1, 2, 3, 5, 3, 5, 3)

# %%
L1[0]
# Out:
# 'hello'

# %%
L1[0]="hii"

# %%
L1
# Out:
# ['hii', 'this', 'is', 'list', 1, 3, 5, 4.64, False, True]

# %%
# set
s={2,34,12,3,1,3,1,4,4,6,4,5}
print(s)
# Out:
# {1, 2, 3, 34, 4, 6, 5, 12}

# %%
# Dictionary
D={"name":"pihu","contact":2345,"age":20,'address':'Noida'}
print(D)
# Out:
# {'name': 'pihu', 'contact': 2345, 'age': 20, 'address': 'Noida'}

# %%
type(D)
# Out:
# dict

# %%
D["name"]
# Out:
# 'pihu'

# %%
D["name"]="madhur"

# %%
print(D)
# Out:
# {'name': 'madhur', 'contact': 2345, 'age': 20, 'address': 'Noida'}

# %% [markdown]
# # keywords

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# # Questions

# %%
N={"name":"pihu"}   #Q1

# %%
print(name)
# Out:
# pihu

# %%
print(N)
# Out:
# {'name': 'pihu'}

# %%
P={"city":"dholakpur","country":"Italy"} #Q2

# %%
print(P)
# Out:
# {'city': 'dholakpur', 'country': 'Italy'}

# %%
print("hello")
print("python")       #Q3
print("world")
# Out:
# hello
# python
# world

# %%
m=[1,2,3,4,5]  #Q4
print(m)
# Out:
# [1, 2, 3, 4, 5]

# %%
print('I am learning "Python"')
# Out:
# I am learning "Python"

# %%
print('***')
# Out:
# ***

# %%
Name="Pihu"
Age=17
Course="Data science"

# %%
print(Name)
print(Age)
print(Course)
# Out:
# Pihu
# 17
# Data science

# %%
print("*******")
print("*******")
print("*******")
print("*******")
# Out:
# *******
# *******
# *******
# *******

# %%
print("* "*5)      #q10
print("* "*5)
print("* "*5)
print("* "*5)
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
for i in range (4):
    print("* "*5)
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
