# %% [markdown]
# # 1. Characteristic data(String)

# %% [markdown]
# A -1
# B -2
# C -3
# .
# .
# .

# %%
string1='A'
string2="A"
string3="""A"""

# %%
print(string1)
print(string2)
print(string3)
# Out:
# A
# A
# A

# %% [markdown]
# ![image.png](attachment:34edcc7b-f97d-495d-8edd-711258fed7d1.png)

# %%
chr(65)
# Out:
# 'A'

# %%
chr(70)
# Out:
# 'F'

# %%
chr(90)
# Out:
# 'Z'

# %%
chr(97)
# Out:
# 'a'

# %%
"A"=="a"
# Out:
# False

# %%
ord("A")
# Out:
# 65

# %%
ord("@")
# Out:
# 64

# %%
ord(" ")
# Out:
# 32

# %%
ord("5")
# Out:
# 53

# %% [markdown]
# # function & Methods

# %%
text=" hello it's a python class"

# %%
len(text)
# Out:
# 26

# %%
type(text)
# Out:
# str

# %%
text.upper()
# Out:
# " HELLO IT'S A PYTHON CLASS"

# %%
text.title()
# Out:
# " Hello It'S A Python Class"

# %%
text.capitalize()
# Out:
# " hello it's a python class"

# %%
Txt= "hello everyone . it's a python class"
Txt
# Out:
# "hello everyone . it's a python class"

# %%
Txt.capitalize()
# Out:
# "Hello everyone . it's a python class"

# %%
str1="123"  # digit
str2="abc@" # non alpha-numeric
str3="abc123" #Alphanumeric
str4="abc"   #alphabate

# %%
s1="abc"
s1.isalpha()
# Out:
# True

# %%
s2="abc123"
s2.isalnum()
# Out:
# True

# %%
s3="abc@123"
s3.isalnum()
# Out:
# False
